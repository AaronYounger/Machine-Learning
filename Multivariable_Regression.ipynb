# %% [markdown]
# <a href="https://colab.research.google.com/github/AaronYounger/Machine-Learning/blob/main/Multivariable_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Multivariable Regression

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
import math
import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline

df = pd.read_csv("homeprices-MV.csv")

median_bedrooms = math.floor(df.bedrooms.median())
median_bedrooms

df.bedrooms = df.bedrooms.fillna(median_bedrooms)
df

reg = linear_model.LinearRegression()
reg.fit(df[['area', 'bedrooms', 'age']], df.price)
prediction = reg.predict([[4010, 4, 12]])
print(prediction)
reg.score(df[['area', 'bedrooms', 'age']], df.price)
# Out:
# [748097.5]
# 0.9488817891373802
